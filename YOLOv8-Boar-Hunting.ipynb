# %%
# !gdown https://drive.google.com/uc?id=1PaAYyNPF4YwqeW5jeR1KIUBy7wi_In1c

# %%
# !unzip Wild-Boar.zip

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
model=YOLO()
model.train(data="/content/Wild-Boar/data.yaml",epochs=50)
